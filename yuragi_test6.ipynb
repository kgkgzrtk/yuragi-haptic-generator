# %% [markdown]
# <a href="https://colab.research.google.com/github/fasl/yuragi-haptic-generator/blob/main/yuragi_test6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# Copy the zip file from Drive to the Colab environment
# !cp "/content/yuragi-haptic-generator.zip" .

# Unzip the copied file
# !unzip ./yuragi-haptic-generator.zip

#!cp -r /content/yuragi-haptic-generator/ .
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Archive:  ./yuragi-haptic-generator.zip
# a28bc12148ed471fd5f0ce99a309994c1079f5e5
#    creating: yuragi-haptic-generator-main/
#    creating: yuragi-haptic-generator-main/.github/
#    creating: yuragi-haptic-generator-main/.github/workflows/
#   inflating: yuragi-haptic-generator-main/.github/workflows/ci.yml
#   inflating: yuragi-haptic-generator-main/.npmrc
#   inflating: yuragi-haptic-generator-main/CONTRIBUTING.md
#   inflating: yuragi-haptic-generator-main/DEPLOYMENT.md
#   inflating: yuragi-haptic-generator-main/LICENSE
#   inflating: yuragi-haptic-generator-main/README.md
#    creating: yuragi-haptic-generator-main/backend/
#   inflating: yuragi-haptic-generator-main/backend/.dockerignore
#   inflating: yuragi-haptic-generator-main/backend/.env.development
#   inflating: yuragi-haptic-generator-main/backend/.env.example
#   inflating: yuragi-haptic-generator-main/backend/.env.production
#   inflating: yuragi-haptic-generator-main/backend/Dockerfile
#   inflating: yuragi-haptic-generator-main/backend/README.md
#   inflating: yuragi-haptic-generator-main/backend/TDD_DEVELOPMENT_REPORT.md
#   inflating: yuragi-haptic-generator-main/backend/example_usage.py
#   inflating: yuragi-haptic-generator-main/backend/pyproject.toml
#    creating: yuragi-haptic-generator-main/backend/src/
#  extracting: yuragi-haptic-generator-main/backend/src/__init__.py
#    creating: yuragi-haptic-generator-main/backend/src/config/
#  extracting: yuragi-haptic-generator-main/backend/src/config/__init__.py
#   inflating: yuragi-haptic-generator-main/backend/src/config/logging.py
#   inflating: yuragi-haptic-generator-main/backend/src/config/settings.py
#    creating: yuragi-haptic-generator-main/backend/src/haptic_system/
#   inflating: yuragi-haptic-generator-main/backend/src/haptic_system/__init__.py
#   inflating: yuragi-haptic-generator-main/backend/src/haptic_system/channel.py
#   inflating: yuragi-haptic-generator-main/backend/src/haptic_system/controller.py
#   inflating: yuragi-haptic-generator-main/backend/src/haptic_system/device.py
#   inflating: yuragi-haptic-generator-main/backend/src/haptic_system/waveform.py
#   inflating: yuragi-haptic-generator-main/backend/src/main.py
#   inflating: yuragi-haptic-generator-main/backend/src/server.py
#    creating: yuragi-haptic-generator-main/backend/tests/
#  extracting: yuragi-haptic-generator-main/backend/tests/__init__.py
#    creating: yuragi-haptic-generator-main/backend/tests/haptic_system/
#   inflating: yuragi-haptic-generator-main/backend/tests/haptic_system/test_resonator.py
#    creating: yuragi-haptic-generator-main/backend/tests/integration/
#  extracting: yuragi-haptic-generator-main/backend/tests/integration/__init__.py
#   inflating: yuragi-haptic-generator-main/backend/tests/integration/test_api_integration.py
#   inflating: yuragi-haptic-generator-main/backend/tests/integration/test_signal_pipeline.py
#    creating: yuragi-haptic-generator-main/backend/tests/unit/
#   inflating: yuragi-haptic-generator-main/backend/tests/unit/test_16_direction_mode.py
#   inflating: yuragi-haptic-generator-main/backend/tests/unit/test_haptic_channel.py
#   inflating: yuragi-haptic-generator-main/backend/tests/unit/test_haptic_controller.py
#   inflating: yuragi-haptic-generator-main/backend/tests/unit/test_haptic_device.py
#   inflating: yuragi-haptic-generator-main/backend/tests/unit/test_noise_simulation.py
#   inflating: yuragi-haptic-generator-main/backend/tests/unit/test_sawtooth_waveform.py
#   inflating: yuragi-haptic-generator-main/backend/uv.lock
#    creating: yuragi-haptic-generator-main/config/
#    creating: yuragi-haptic-generator-main/config/fluentd/
#   inflating: yuragi-haptic-generator-main/config/fluentd/fluent.conf
#   inflating: yuragi-haptic-generator-main/docker-compose.dev.yml
#   inflating: yuragi-haptic-generator-main/docker-compose.logging.yml
#   inflating: yuragi-haptic-generator-main/docker-compose.yml
#    creating: yuragi-haptic-generator-main/docs/
#   inflating: yuragi-haptic-generator-main/docs/00_index.md
#    creating: yuragi-haptic-generator-main/docs/01_project/
#   inflating: yuragi-haptic-generator-main/docs/01_project/project_analysis.md
#   inflating: yuragi-haptic-generator-main/docs/01_project/project_overview_latest.md
#   inflating: yuragi-haptic-generator-main/docs/01_project/project_summary.md
#    creating: yuragi-haptic-generator-main/docs/02_requirements/
#   inflating: yuragi-haptic-generator-main/docs/02_requirements/draft_requirements.md
#   inflating: yuragi-haptic-generator-main/docs/02_requirements/system_requirements.md
#    creating: yuragi-haptic-generator-main/docs/03_design/
#   inflating: yuragi-haptic-generator-main/docs/03_design/software_design.md
#   inflating: yuragi-haptic-generator-main/docs/03_design/software_design_mvp.md
#    creating: yuragi-haptic-generator-main/docs/05_testing/
#   inflating: yuragi-haptic-generator-main/docs/05_testing/tdd_test_design.md
#    creating: yuragi-haptic-generator-main/docs/06_implementation/
#   inflating: yuragi-haptic-generator-main/docs/06_implementation/mvp_implementation_plan.md
#    creating: yuragi-haptic-generator-main/docs/07_implementation/
#   inflating: yuragi-haptic-generator-main/docs/07_implementation/api_documentation.md
#   inflating: yuragi-haptic-generator-main/docs/07_implementation/waveform_rendering_websocket.md
#    creating: yuragi-haptic-generator-main/frontend/
#   inflating: yuragi-haptic-generator-main/frontend/.dockerignore
#   inflating: yuragi-haptic-generator-main/frontend/.env.development
#   inflating: yuragi-haptic-generator-main/frontend/.env.example
#   inflating: yuragi-haptic-generator-main/frontend/.env.production
#   inflating: yuragi-haptic-generator-main/frontend/.eslintignore
#   inflating: yuragi-haptic-generator-main/frontend/.eslintrc.cjs
#   inflating: yuragi-haptic-generator-main/frontend/.prettierignore
#   inflating: yuragi-haptic-generator-main/frontend/.prettierrc
#   inflating: yuragi-haptic-generator-main/frontend/Dockerfile
#   inflating: yuragi-haptic-generator-main/frontend/index.html
#   inflating: yuragi-haptic-generator-main/frontend/nginx.conf
#   inflating: yuragi-haptic-generator-main/frontend/package.json
#   inflating: yuragi-haptic-generator-main/frontend/playwright.config.ts
#    creating: yuragi-haptic-generator-main/frontend/src/
#   inflating: yuragi-haptic-generator-main/frontend/src/App.css
#   inflating: yuragi-haptic-generator-main/frontend/src/App.tsx
#    creating: yuragi-haptic-generator-main/frontend/src/components/
#    creating: yuragi-haptic-generator-main/frontend/src/components/Common/
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Common/Button.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Common/DeviceWarningDialog.css
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Common/DeviceWarningDialog.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Common/Input.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Common/NotificationContainer.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Common/Slider.css
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Common/Slider.tsx
#    creating: yuragi-haptic-generator-main/frontend/src/components/ControlPanel/
#   inflating: yuragi-haptic-generator-main/frontend/src/components/ControlPanel/ChannelControl.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/ControlPanel/HapticControlPanel.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/ControlPanel/VectorControl.tsx
#    creating: yuragi-haptic-generator-main/frontend/src/components/Visualization/
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Visualization/AccelerationTrajectory.css
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Visualization/AccelerationTrajectory.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Visualization/AccelerationTrajectoryContainer.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Visualization/WaveformChart.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/Visualization/WaveformChartContainer.tsx
#    creating: yuragi-haptic-generator-main/frontend/src/components/__tests__/
#   inflating: yuragi-haptic-generator-main/frontend/src/components/__tests__/ChannelControl.test.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/__tests__/VectorControl.test.tsx
#   inflating: yuragi-haptic-generator-main/frontend/src/components/__tests__/WaveformChart.test.tsx
#    creating: yuragi-haptic-generator-main/frontend/src/config/
#   inflating: yuragi-haptic-generator-main/frontend/src/config/environment.ts
#    creating: yuragi-haptic-generator-main/frontend/src/contexts/
#    creating: yuragi-haptic-generator-main/frontend/src/contexts/__tests__/
#   inflating: yuragi-haptic-generator-main/frontend/src/contexts/__tests__/hapticStore.test.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/contexts/hapticStore.ts
#    creating: yuragi-haptic-generator-main/frontend/src/hooks/
#    creating: yuragi-haptic-generator-main/frontend/src/hooks/__tests__/
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/__tests__/useParametersQuery.test.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/__tests__/useWebSocket.test.ts
#    creating: yuragi-haptic-generator-main/frontend/src/hooks/queries/
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/queries/index.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/queries/useDeviceQuery.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/queries/useHealthQuery.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/queries/useParametersQuery.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/queries/useStreamingQuery.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/queries/useVectorForceQuery.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/queries/useWaveformQuery.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/useErrorHandler.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/useQueryStoreIntegration.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/hooks/useWebSocket.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/index.css
#   inflating: yuragi-haptic-generator-main/frontend/src/index.tsx
#    creating: yuragi-haptic-generator-main/frontend/src/lib/
#   inflating: yuragi-haptic-generator-main/frontend/src/lib/queryClient.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/lib/zustandQuerySync.ts
#    creating: yuragi-haptic-generator-main/frontend/src/services/
#   inflating: yuragi-haptic-generator-main/frontend/src/services/hapticService.ts
#    creating: yuragi-haptic-generator-main/frontend/src/test/
#    creating: yuragi-haptic-generator-main/frontend/src/test/mocks/
#   inflating: yuragi-haptic-generator-main/frontend/src/test/mocks/chartjs.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/test/mocks/hapticService.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/test/mocks/index.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/test/mocks/websocket.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/test/setup.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/test/test-utils.tsx
#    creating: yuragi-haptic-generator-main/frontend/src/types/
#   inflating: yuragi-haptic-generator-main/frontend/src/types/hapticTypes.ts
#    creating: yuragi-haptic-generator-main/frontend/src/utils/
#   inflating: yuragi-haptic-generator-main/frontend/src/utils/chartConfig.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/utils/logger.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/utils/waveformGenerator.test.ts
#   inflating: yuragi-haptic-generator-main/frontend/src/utils/waveformGenerator.ts
#    creating: yuragi-haptic-generator-main/frontend/tests/
#    creating: yuragi-haptic-generator-main/frontend/tests/e2e/
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/README.md
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/app.smoke.spec.ts
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/error-handling.spec.ts
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/example.spec.ts
#    creating: yuragi-haptic-generator-main/frontend/tests/e2e/fixtures/
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/fixtures/testData.ts
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/haptic-controls.spec.ts
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/responsive-design.spec.ts
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/streaming-controls.spec.ts
#    creating: yuragi-haptic-generator-main/frontend/tests/e2e/utils/
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/utils/testHelpers.ts
#   inflating: yuragi-haptic-generator-main/frontend/tests/e2e/vector-controls.spec.ts
#   inflating: yuragi-haptic-generator-main/frontend/tsconfig.json
#   inflating: yuragi-haptic-generator-main/frontend/tsconfig.node.json
#   inflating: yuragi-haptic-generator-main/frontend/vite.config.ts
#   inflating: yuragi-haptic-generator-main/pnpm-lock.yaml
#  extracting: yuragi-haptic-generator-main/pnpm-workspace.yaml
#   inflating: yuragi-haptic-generator-main/pyproject.toml
#    creating: yuragi-haptic-generator-main/scripts/
#   inflating: yuragi-haptic-generator-main/scripts/backup.sh
#   inflating: yuragi-haptic-generator-main/scripts/deploy.sh
#   inflating: yuragi-haptic-generator-main/scripts/monitor.sh
#   inflating: yuragi-haptic-generator-main/scripts/run-e2e-tests.sh
#   inflating: yuragi-haptic-generator-main/setup-dev.sh
#   inflating: yuragi-haptic-generator-main/test_local_waveform.py
#   inflating: yuragi-haptic-generator-main/uv.lock

# %%
# %cd yuragi-haptic-generator-main
# !pwd
# !curl -LsSf https://astral.sh/uv/install.sh | sh
# Out:
# /content/yuragi-haptic-generator-main/frontend/yuragi-haptic-generator-main
# /content/yuragi-haptic-generator-main/frontend/yuragi-haptic-generator-main
# downloading uv 0.8.6 x86_64-unknown-linux-gnu
# no checksums to verify
# installing to /usr/local/bin
#   uv
#   uvx
# everything's installed!

# %%
# Python仮想環境と依存関係のインストール
#!uv venv
#!source .venv/bin/activate  # Windows: .venv\Scripts\activate
# !uv pip install -e .

# 開発用依存関係を含める場合
# !uv pip install -e ".[dev,test]"
# Out:
# Using Python 3.11.13 environment at: /usr
# Resolved 24 packages in 40ms
#    Building yuragi-haptic-generator @ file:///content/yuragi-haptic-generator-main/f
#    Building yuragi-haptic-generator @ file:///content/yuragi-haptic-generator-main/f
#    Building yuragi-haptic-generator @ file:///content/yuragi-haptic-generator-main/f
#       Built yuragi-haptic-generator @ file:///content/yuragi-haptic-generator-main/f
# Prepared 1 package in 342ms
# Uninstalled 1 package in 0.46ms
# Installed 1 package in 1ms
#  - yuragi-haptic-generator==0.1.0 (from file:///content/yuragi-haptic-generator-main/backend/yuragi-haptic-generator-main)
#  + yuragi-haptic-generator==0.1.0 (from file:///content/yuragi-haptic-generator-main/frontend/yuragi-haptic-generator-main)
# Using Python 3.11.13 environment at: /usr
# Resolved 46 packages in 39ms
#    Building yuragi-haptic-generator @ file:///content/yuragi-haptic-generator-main/f
#    Building yuragi-haptic-generator @ file:///content/yuragi-haptic-generator-main/f
#       Built yuragi-haptic-generator @ file:///content/yuragi-haptic-generator-main/f
# Prepared 1 package in 337ms
# Uninstalled 1 package in 0.70ms
# Installed 1 package in 1ms
#  ~ yuragi-haptic-generator==0.1.0 (from file:///content/yuragi-haptic-generator-main/frontend/yuragi-haptic-generator-main)

# %%
# !pwd
# %cd /content/yuragi-haptic-generator-main/backend
# !pwd

# install protaudio
# !sudo apt install portaudio19-dev
# !pip install sounddevice

# 依存関係のインストール
# !uv pip install -e ".[dev,api]"

# サーバーの起動
# !uv run uvicorn src.main:app --reload
# Out:
# /content/yuragi-haptic-generator-main/frontend
# /content/yuragi-haptic-generator-main/backend
# /content/yuragi-haptic-generator-main/backend
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# portaudio19-dev is already the newest version (19.6.0-1.1).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Requirement already satisfied: sounddevice in /usr/local/lib/python3.11/dist-packages (0.5.2)
# Requirement already satisfied: CFFI>=1.0 in /usr/local/lib/python3.11/dist-packages (from sounddevice) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from CFFI>=1.0->sounddevice) (2.22)
# Using Python 3.11.13 environment at: /usr
# Resolved 38 packages in 37ms
#    Building haptic-system @ file:///content/yuragi-haptic-generator-main/backend
#    Building haptic-system @ file:///content/yuragi-haptic-generator-main/backend
#       Built haptic-system @ file:///content/yuragi-haptic-generator-main/backend
# Prepared 1 package in 316ms
# Uninstalled 1 package in 0.38ms
# Installed 1 package in 0.92ms
#  ~ haptic-system==0.1.0 (from file:///content/yuragi-haptic-generator-main/backend)
# INFO:     Will watch for changes in these directories: ['/content/yuragi-haptic-generator-main/backend']
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# INFO:     Started reloader process [25474] using WatchFiles
# 2025-08-08 12:49:33,954 - src.config.settings - INFO - Application starting
# Available devices: 0
# 2025-08-08 12:49:33,954 - src.main - INFO - HapticController initialized with sample_rate=44100, block_size=512
# 2025-08-08 12:49:33,955 - src.main - INFO - CORS configured with origins: ['http://localhost:3000']
# INFO:     Started server process [25476]
# INFO:     Waiting for application startup.
# 2025-08-08 12:49:33,968 - src.main - INFO - Starting application...
# 2025-08-08 12:49:33,968 - src.main - INFO - Background waveform streaming task started
# INFO:     Application startup complete.
# INFO:     Shutting down
# INFO:     Waiting for application shutdown.
# 2025-08-08 12:50:14,900 - src.main - INFO - Shutting down application...
# 2025-08-08 12:50:14,900 - src.main - INFO - Background waveform streaming task stopped
# 2025-08-08 12:50:14,900 - src.main - INFO - Application shutdown complete
# INFO:     Application shutdown complete.
# INFO:     Finished server process [25476]
# INFO:     Stopping reloader process [25474]

# %%
# pnpmのインストール（未インストールの場合）
#!pwd
# %cd /content/yuragi-haptic-generator-main/frontend

# !apt-get update
#!apt-get install nodejs npm
# !sudo npm install -g pnpm
# !pnpm -v

#!curl -fsSL https://get.pnpm.io/install.sh | sh -

#!pnpm install
#!pnpm dev
# Out:
# /content/yuragi-haptic-generator-main/frontend
# Hit:1 http://archive.ubuntu.com/ubuntu jammy InRelease
# Hit:2 http://archive.ubuntu.com/ubuntu jammy-updates InRelease
# Hit:3 http://archive.ubuntu.com/ubuntu jammy-backports InRelease
# Hit:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# Hit:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease
# Hit:6 http://security.ubuntu.com/ubuntu jammy-security InRelease
# Hit:7 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Hit:10 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Reading package lists... Done
# W: Skipping acquire of configured file 'main/source/Sources' as repository 'https://r2u.stat.illinois.edu/ubuntu jammy InRelease' does not seem to provide it (sources.list entry misspelt?)
# yuragi-haptic-generator-frontend@0.1.0
#
# npm WARN EBADENGINE Unsupported engine {
# npm WARN EBADENGINE   package: 'pnpm@10.14.0',
# npm WARN EBADENGINE   required: { node: '>=18.12' },
# npm WARN EBADENGINE   current: { node: 'v12.22.9', npm: '8.5.1' }
# npm WARN EBADENGINE }
#
# changed 1 package, and audited 2 packages in 2s
#
# 1 package is looking for funding
#   run `npm fund` for details
#
# found 0 vulnerabilities
# /usr/local/lib/node_modules/pnpm/bin/pnpm.cjs:18
#   if(!require('module')?.enableCompileCache?.())
#                         ^
#
# SyntaxError: Unexpected token '.'
#     at wrapSafe (internal/modules/cjs/loader.js:915:16)
#     at Module._compile (internal/modules/cjs/loader.js:963:27)
#     at Object.Module._extensions..js (internal/modules/cjs/loader.js:1027:10)
#     at Module.load (internal/modules/cjs/loader.js:863:32)
#     at Function.Module._load (internal/modules/cjs/loader.js:708:14)
#     at Function.executeUserEntryPoint [as runMain] (internal/modules/run_main.js:60:12)
#     at internal/main/run_main_module.js:17:47
